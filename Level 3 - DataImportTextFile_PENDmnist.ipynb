# %% [markdown]
# ### change directory and list directory

# %%
import os

# %%
wd = os.getcwd()

# %%
wd = "C:\\Users\\Prasanna\\Desktop\\DATASCIENCE\\"

# %%
os.chdir('C:\\Users\\Prasanna\\Desktop\\DATASCIENCE\\ds_assignments\\')

# %%
os.getcwd()
#os.listdir()
# Out:
# 'C:\\Users\\Prasanna\\Desktop\\DATASCIENCE\\ds_assignments'

# %% [markdown]
# ### Import plain text file and read using open()

# %%
sam_file = open("sample.txt", mode='r')

# %%
type(sam_file)
# Out:
# _io.TextIOWrapper

# %%
sam_file.closed
# Out:
# False

# %%
sam_file.close()

# %%
sam_file.closed
# Out:
# True

# %%
sam_file.readable()
# Out:
# True

# %%
sam_file.readline()
# Out:
# 'This is first sample.\n'

# %%
sam_file.read()
# Out:
# 'There are a lot of such files to read and write.\nWe are currently importing plain text from files using python.'

# %%
sam_file.readlines()
# Out:
# []

# %% [markdown]
# ### File operation using open() and with conjugte

# %%
with open("sample.txt") as samp_f:
    print(samp_f.readlines())
# Out:
# ['This is first sample.\n', 'There are a lot of such files to read and write.\n', 'We are currently importing plain text from files using python.']

# %% [markdown]
# footnote: with conjugate will automatically close the file on which it performs operation. Hence no explicit close()

# %% [markdown]
# ### MNIST file and create image test. example captcha

# %%
#import package
import numpy as nm
#Load file as array : digits
digits = nm.loadtxt()

# %% [markdown]
# ### import from txt file using numpy package

# %% [markdown]
# ##### 1) np.loadtxt()

# %%
import numpy as np
txt_file = np.loadtxt?

# %%
txt_file = np.loadtxt(fname = 'emp_data.txt', delimiter=',',comments='#',dtype = str)
type(txt_file)
txt_file.shape
txt_file
# Out:
# array([['101', "'Geetha'", "'IT'", '100000'],
#        ['102', "'Prasanna'", "'Mgr'", '120000'],
#        ['103', "'Himanish'", "'Trainee'", '50000'],
#        ['104', "'Pracheth'", "'Data Scientist'", '200000'],
#        ['105', "'Kritarth'", "'Space research'", '200000'],
#        ['106', "'Ram Reddy", "'Tutor'", '150000']], dtype='<U16')

# %%
#Read first 4 rows and all columns
print(txt_file[0:5,0:])
# Out:
# [['101' "'Geetha'" "'IT'" '100000']
#  ['102' "'Prasanna'" "'Mgr'" '120000']
#  ['103' "'Himanish'" "'Trainee'" '50000']
#  ['104' "'Pracheth'" "'Data Scientist'" '200000']
#  ['105' "'Kritarth'" "'Space research'" '200000']]

# %% [markdown]
# Footnote: The above method shall read single datatype (or compatible to be converted). To overcome, we comeup with reading of mixed datatypes

# %% [markdown]
# ##### 2) np.genfromtxt()

# %%
import numpy as nu
os.getcwd()
# Out:
# 'C:\\Users\\Prasanna\\Desktop\\DATASCIENCE\\ds_assignments'

# %%
mx_txt = nu.genfromtxt(fname='EMP.txt', delimiter=',',names =True, dtype=None)
type(mx_txt)
#print(mx_txt)
#other way of knowing shape is from package alias nu
#print(nu.shape(mx_txt))
# Out:
# C:\Users\Prasanna\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   """Entry point for launching an IPython kernel.
# numpy.ndarray

# %% [markdown]
# IMPORTANT: we get an error/warning if we donot have the column header in the first line and even if we have comment starting with #

# %%
print(mx_txt['SAL'])
# Out:
# [ 960 1600 1250 2975 1250 2850 2450 3000 5000 1500 1100  950 3000 1300]

# %%
#Plot a scatter plot of mx_txt data

# %%
#from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
plt.scatter(mx_txt['SAL'],mx_txt['COMM'])
plt.xlabel('Sal')
plt.ylabel('Comm')
#plt.show()
# Out:
# Text(0,0.5,'Comm')

# %% [markdown]
# ### import using pandas

# %% [markdown]
# We can read mixed datatypes in 3 ways 1)numpy genfromtxt() for flat files 2) pandas read_csv for CSV files.

# %%
import pandas as pd
#assign the file name
sales_df = pd.read_csv("C:\\Users\\Prasanna\\Desktop\\DATASCIENCE\\01 Data Science Lab Copy\\02 Lab Data\\Python\\pandas_sales.csv")
emp_df.head()
#to read first few rows
dept_df3 = pd.read_csv("dept_merge.csv",nrows=3,header=None)#remove header=None, u get 3 data rows with column heading
dept_df3
#convert dataframe into ndarray 
sales_nd = sales_df.values
sales_nd
# Out:
# array([['Jan', 47, 12.0, 17],
#        ['Feb', 110, 50.0, 31],
#        ['Mar', 221, 89.0, 72],
#        ['Apr', 77, 87.0, 20],
#        ['May', 132, nan, 52],
#        ['Jun', 205, 60.0, 55]], dtype=object)

# %% [markdown]
# ##### Exploring read_csv() method parameters

# %%
#C:\\Users\\Prasanna\\Desktop\\DATASCIENCE\\01 Data Science Lab Copy\\02 Lab Data\\Python\\titanic.csv
cars = pd.read_csv("C:\\Users\\Prasanna\\Desktop\\DATASCIENCE\\01 Data Science Lab Copy\\02 Lab Data\\train.csv", sep = ',', na_values=["omg"])
cars
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# ## Check: na_values is not showing custom msg for NaN
